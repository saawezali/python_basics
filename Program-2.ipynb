# %%
x1= int(input("enter X1 value"))
x2= int(input("enter X2 value"))
y1= int(input("enter y1 value"))
y2= int(input("enter y2 value"))
result=(((x2-x1)**2 + (y2-y1)**2)**0.5)
print("the distance between two points",(x1,x2),"and",(y1,y2),"=",result)
# Out:
# the distance between two points (2, 3) and (32, 11) = 21.02379604162864

# %%
num1=int(input("Enter the first number"))
num2=int(input("Enter the second number"))
print(f"The sum of the two numbers is {num1+num2}")
# Out:
# The sum of the two numbers is 854

# %%
import sys
sys.argv = ['C:/Users/lappyowner/OneDrive/Desktop/college/Python/add.py', '10', '20']

num1 = int(sys.argv[1])
num2 = int(sys.argv[2])

print(f"Sum = {num1 + num2}")
# Out:
# Sum = 30
