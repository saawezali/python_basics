# %%
# Program - 4.1
my_list = [10, 20, 30, 40]
my_tuple = (10, 20, 30, 40)
print("List elements:")
for item in my_list:
    print(item)
print("Tuple elements:")
for item in my_tuple:
    print(item)
# Out:
# List elements:
# 10
# 20
# 30
# 40
# Tuple elements:
# 10
# 20
# 30
# 40

# %%
# Program - 4.2
# For Loop
sequence = [1, 2, 3, 4, 5]
for i in sequence:
    print(i)

# While Loop
num = int(input("Enter a number: "))
while num >= 0:
    print(num)
    num -= 1
# Out:
# 1
# 2
# 3
# 4
# 5
# Enter a number:  8
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0
