# %%
# set datatype 
# a={10,20,30,30,30}
a={10,20,30,30,30}
print(a)
print(type(a))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
# Q1. wap to add two number input should be taken from user datatype <int,float>
a=int(input("Enter the first number: "))
b=float(input("Enter the second number: "))

print("Type of first number: ",type(a))
print("Type of second number: ",type(b))
# Out:
# Type of first number:  <class 'int'>
# Type of second number:  <class 'float'>

# %%
# CHECK THAT A GIVEN NUMBER IF EVEN OR ODD
a=int(input("Enter the number: "))
if a%2==0:
    print(f"{a} is an even number.")
    
else:
    print(f"{a} is an odd number.")
# Out:
# 5 is an odd number.

# %%
# LARGEST AMONG 2 NUMBER
a=int(input("Enter the first number: "))
b=int(input("Enter the second number: "))
if a>b:
    print(f"{a} is the largest number.")

elif a<b:
    print(f"{b} is the largest number.")

else:
    print("Both are equal.")
# Out:
# 9 is the largest number.

# %%
# check the given number is prime or not
a=int(input("ENTER THE NUMBER: "))
if a<=1:
    print("Non prime : ",a)

else:
    for i in range (2,a):
        if(a%i==0):
            print(f"{a} is a non prime number.")
            break

    else:
        print(f"{a} is a prime number.")
# Out:
# 17 is a prime number.

# %%
# Find the CI and take the value from the user.

Principal=int(input("Enter the Principal amount: "))
Time=int(input("Enter the Time: "))
Rate=int(input("Enter the Rate: "))
result=Principal*((1+(Rate/100))**Time)
print("Compound Interest : ",result)
# Out:
# Compound Interest :  1159.2740743000002
